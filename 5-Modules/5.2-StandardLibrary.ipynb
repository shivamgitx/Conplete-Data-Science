# %% [markdown]
# ## Standard Library Overview
#
# Python's standard library is a vast collection of modules and packages that come bundled with python , providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
#random
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','orange']))
# Out:
# 8
# orange

# %%
## File and Directory Access

import os
print(os.getcwd())
# Out:
# /Users/shinchan/Desktop/Complete Data Science/5-Modules

# %%
os.mkdir('test_dir')

# %%
## High level operations on files and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Seialization

import json
data={'name':'Shivam','age':24}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Shivam", "age": 24}
# <class 'str'>
# {'name': 'Shivam', 'age': 24}
# <class 'dict'>

# %% [markdown]
# Python includes a built-in json module in its standard library for working with JSON (JavaScript Object Notation) data. This module allows you to convert Python objects into JSON format (serialization/encoding) and convert JSON data back into Python objects (deserialization/decoding).
#
# To use the module, you first need to import it:
# import json
#
# Core Functions:
#
#
# json.dumps():converts a Python object to a JSON formatted string (Generating a JSON string from a Python dictionary)
#
#
# json.loads():Converts a JSON formatted string to a Python object (Parsing JSON data received from an API as a string)
#
#
# json.dump():Serializes a Python object and writes it to a file (Storing Python data in a .json file)
#
#
# json.load():Deserializes a JSON formatted file into a Python object (Reading configuration or data from a .json file)

# %%
## Csv

import csv

with open ('example.csv',mode='w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Shivam','24'])
with open('example.csv', mode='r')as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Shivam', '24']

# %%
##datetime

from datetime import datetime, timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-03-25 16:43:31.459719
# 2026-03-24 16:43:31.459719

# %%
##time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1774437330.338072
# 1774437332.343337

# %%
## regular expression
import re

pattern=r'\d+'
text='There are 123 apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
