# %% [markdown]
# ## Exception Hnadling
#
# Exception Hnadling in pyhton allows you to handle errors gracefully and take corrective actions without stopping the execution of the program.
#
# ### What are Exceptions?
#
# Exceptions are events that disrupts the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
#
# 1-ZeroDivisionError:Dividing by zero
#
# 2-FileNotFoundError:File not found
#
# 3-ValueError:Invalid value
#
# 4-TypeError:Invalid type

# %%
##Exception try, except block

try:
    a=b
except:
    print("The variable is not assigned")
# Out:
# The variable is not assigned

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result=1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Cannot divide by zero")
# Out:
# division by zero
# Cannot divide by zero

# %%
try:
    result=1/3
    a=b
except ZeroDivisionError as ex:  #it willl not execute bcz it have not zero divison error
    print(ex)
    print("Cannot divide by zero")
except NameError as ex:
    print(ex)
    print("The variable is not assigned")
# Out:
# name 'b' is not defined
# The variable is not assigned

# %%
try:
    num=int(input("Enter a number"))
    result=10/num
except ValueError:
    print("This is not a valid number") 
except ZeroDivisionError:
    
    print("eneter denominaor greater than 0")
# Out:
# This is not a valid number

# %%
##try, except, else block
try:
    num=int(input("Enter a number"))
    result=10/num
except ValueError:
    print("This is not a valid number") 
except ZeroDivisionError:
    print("eneter denominator greater than 0") 
else:
    print(result)
