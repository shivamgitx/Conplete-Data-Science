# %% [markdown]
# # Flask Framework
#
# Web framework which is created with the help of python programming language.(It provides the essential core tools needed to build web applications )
#
# ### Key Components:
#
# 1-WSGI(Webserver Gateway Interface) : it follows a standard protocol that allows it to communicate with web servers
#
# 2-Jinja 2 Template Engine : it allows developers to create dynamic web pages by embedding Python-like logic—such as variables, loops, and conditional statements—directly into HTML files

# %%
# wsgi

# Req1 (/home)  ───────▶
# Req2          ───────▶        +------------------+
# Req3          ───────▶        |    Web Server   |
#                               +------------------+
#                                         ⇅
#                              (WSGI Communication)
#                                         ⇅
#                               +------------------+
#                               |      Web App     |  → Flask Framework
#                               +------------------+
#                                   /home
#                                   /API
#                                   /functionalities
