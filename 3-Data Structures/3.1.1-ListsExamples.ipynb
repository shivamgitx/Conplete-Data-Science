# %% [markdown]
# ## Real World Examples Using Lists in Python
#
# Lists are one of the most commonly used data structures in python, thanks to their versatility and ease of use.Here are several practical examples that illustarte their use in real world scenerios

# %% [markdown]
# ### Example 1.Manage A To Do List
#
# create a to do list to keep track of tasks

# %%
to_do_list=["Buy Groceries","Clean the house","Pay bills"]

## Adding to task
to_do_list.append("Shedule Meeting")
to_do_list.append("Go for a run")

## Removing a complete task
to_do_list.remove("Clean the house")

## Checking if a task is in the list
if "Pay bills" in to_do_list:
    print("Dont forget to pay the utility bills")

print("To Do List Remaining")    
for task in to_do_list:
    print(f"-{task}")
# Out:
# Dont forget to pay the utility bills
# To Do List Remaining
# -Buy Groceries
# -Pay bills
# -Shedule Meeting
# -Go for a run

# %% [markdown]
# ### Example 2: Organize Student Grades
#
# create a list to store and calculate average grades for students

# %%
# Organizing students grades
grades=[85,92,78,90,88]

# Adding a new grade
grades.append(95)

# Calculating the average grade 
average_grade = sum(grades)/len(grades)
print(f"Average Grade: {average_grade:.2f}")

# Finding the highest nd lowest grades
highest_grade=max(grades)
lowest_grade=min(grades)
print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grade: {lowest_grade}")
# Out:
# Average Grade: 88.00
# Highest Grade: 95
# Lowest Grade: 78

# %% [markdown]
# ### Example 3:Managung an Inventory
#
# Use a list to manage nventory items in store

# %%
# Managing an Inventory
inventory=["apples","bananas","oranges","grapes"]

# Adding a new item
inventory.append("strawberries")

# Removing an item that is out of stock
inventory.remove("bananas")

# Checking if an item is in stock
item="oranges"
if item in inventory:
    print(f"{item} is in stock")
else:
    print(f"{item} is not in stock")


# PRINTING THE INVENTORY
print("Inventory Remaining")
for item in inventory:
    print(f"-{item}")
# Out:
# oranges is in stock
# Inventory Remaining
# -apples
# -oranges
# -grapes
# -strawberries

# %% [markdown]
# ### Exapmle 4: Collecting Users Feedback
#
# Use a list to collect and analyze user feedback.

# %%
# Collecting user feedback
feedback=["Great Service!","Very Satisfied","Cloud be better","Excellent experience"]

# Adding a new feedback
feedback.append("Not happy with the service")

# Counting specific feedback
positive_feedback_count= sum(1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower())
print(f"Positive Feedback Count: {positive_feedback_count}")

# Printing all feedback

print("User feedback:")
for comment in feedback:
    print(f"-{comment}")
# Out:
# Positive Feedback Count: 2
# User feedback:
# -Great Service!
# -Very Satisfied
# -Cloud be better
# -Excellent experience
# -Not happy with the service
