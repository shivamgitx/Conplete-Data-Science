# %% [markdown]
# ### Decorators
#
# Decorators are powerful and flexible feature in python that allows you to modify the behavior of a function or a class method. They are commonly used to add functionality to functions or method without odifying thier actual code.

# %%
##function copy
##closures 
##decorators

# %%
## function copy
def welcome():
    return "welcome to the advance python course"

welcome()
# Out:
# 'welcome to the advance python course'

# %%
wel=welcome
print(wel())
del welcome
print(wel())
# Out:
# welcome to the advance python course
# welcome to the advance python course

# %%
## Closures : afuction inside a function

def main_welcome():
    msg="welcome"
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(msg)       # to get the msg variable also
        print("plzz learn these concept properly")
    return sub_welcome_method()

# %%
main_welcome()
# Out:
# Welcome to the advance python course
# welcome
# plzz learn these concept properly

# %%
def main_welcome(msg):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(msg)       # to get the msg variable also
        print("plzz learn these concept properly")
    return sub_welcome_method()

# %%
main_welcome("welcome evryone")
# Out:
# Welcome to the advance python course
# welcome evryone
# plzz learn these concept properly

# %%
## replacin msg to function

def main_welcome(func):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        func("Hello")       
        print("plzz learn these concept properly")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# Welcome to the advance python course
# Hello
# plzz learn these concept properly

# %%
## in closure you can probably dfine methods ,pass method inside method, parameter as method

# %%
def main_welcome(func,lst):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(func(lst))      
        print("plzz learn these concept properly")
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5,6])
# Out:
# Welcome to the advance python course
# 6
# plzz learn these concept properly

# %%
## Decorators

def main_welcome(func):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        func()
        print("plzz learn these concept properly")
    return sub_welcome_method()

# %%
##creating another custom method

def course_introduction():
    print("this is advance python course")

course_introduction()
# Out:
# this is advance python course

# %%
main_welcome(course_introduction)
# Out:
# Welcome to the advance python course
# this is advance python course
# plzz learn these concept properly

# %%
## without calling the function can i display all the messages and that is where decorators are used.

# %%
@main_welcome   # @ used in decorator     #we're not modifying any code in this im just adding decorator to top of function
def course_introduction():
    print("this is advance python course")
# Out:
# Welcome to the advance python course
# this is advance python course
# plzz learn these concept properly

# %%
## Decorators (2nd example)

def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

# %%
@my_decorator

def say_hello():
    print("Hello!")

# %%
say_hello()
# Out:
# Something is happening before the function is called.
# Hello!
# Something is happening after the function is called.

# %%
## decorators with arguments

def repeat(n):
    def decorator (func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hello():
    print("Hello")

# %%
say_hello()
# Out:
# Hello
# Hello
# Hello

# %% [markdown]
# Decorators are a powerful tool in Python for extending and modifying the behavior of functions and methods.
# They provide a clean and readable way to add functionality such as logging, timing, access control,
# and more without changing the original code. Understanding and using decorators effectively can
# significantly enhance your Python programming skills.
