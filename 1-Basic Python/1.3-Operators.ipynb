# %% [markdown]
# ## Operators

# %% [markdown]
# Python operators are symbols or keywords used to perform operations on values and variables. They are organized into several categories:
#
# 1. Introduction to Operators
# 2. Arithmetic Operators : Addition, Subtraction, Multiplication, Division, Floor Division, Modulus, Exponentiation
# 3. Comparision Operators : Equal to, Not Equal to, Greator than, Less than, Greater than or equal to, Less than or equal to
# 4. Logical operators : AND, OR, NOT

# %%
## Arithmetic Operators

a=20
b=10

add=a+b #addition
sub=a-b #substraction
mul=a*b #multiplication
div=a/b #division
floor=a//b #floor division
modulus=a%b #modulus operation
exp=a**b #exponentiation

print(add)
print(sub)
print(mul)
print(div)
print(floor)
print(modulus)
print(exp)
# Out:
# 30
# 10
# 200
# 2.0
# 2
# 0
# 10240000000000

# %% [markdown]
# ### Comparison Operators

# %%
## Comparison Operators
## == Equal to
a=10
b=10

a==b
# Out:
# True

# %%
str1="Shivam"
str2="Shinchan"

str1==str2
# Out:
# False

# %%
## Not Equal to !=
str1!=str2
# Out:
# True

# %%
str3="Shivam"
str4="Shivam__"
str3!=str4
# Out:
# True

# %%
## grater than >

num1=67
num2=45

num1>num2
# Out:
# True

# %%
## less than <

print(num1<num2)
# Out:
# False

# %%
## greater than or equal to

number1=45
number2=45

number1>=number2
# Out:
# True

# %%
## less than or equal to

number1=44
number2==45

number1<=number2
# Out:
# True

# %% [markdown]
# ### Logical Operators

# %%
## AND, OR, NOT

X=True
Y=True

result =X and Y
print(result)

# %%
X=True
Y=False

result =X and Y
print(result)
# Out:
# False

# %%
## OR
X=False
Y=True

result =X and Y
print(result)
# Out:
# False

# %%
## Not Operator
X=True
not X
# Out:
# False

# %%
X=False
not X
# Out:
# True
