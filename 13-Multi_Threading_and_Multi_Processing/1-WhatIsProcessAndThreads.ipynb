# %% [markdown]
# ## Multi threading and Multi Processing
#
# this is fundamental core to write efficient code in whenever you are developing code.

# %% [markdown]
# #### Topics:
#
# 1- Program
#
# 2- Process
#
# 3- Threads
#
# 4- Examples of Process and Threads

# %% [markdown]
# # Program
#
# A program is a sequence of instruction written in programming language(Python,C++,etc.)

# %% [markdown]
# # Process
#
# It is a simply an instance of a program that is being executed.
#
#
# Process work alog with the OS
#
# Resorces required:

# %%
'''''+----------------+----------------+----------------------+
|  Code Segment  |  Data Segment  |         Heap         |
+----------------+----------------+----------------------+
|      Stack     |               Registers              |
+----------------+--------------------------------------+
|                                                      |
|                                                      |
|                                                      |
|                                                      |
+------------------------------------------------------+'''''
# Out:
# "''+----------------+----------------+----------------------+\n|  Code Segment  |  Data Segment  |         Heap         |\n+----------------+----------------+----------------------+\n|      Stack     |               Registers              |\n+----------------+--------------------------------------+\n|                                                      |\n|                                                      |\n|                                                      |\n|                                                      |\n+------------------------------------------------------+"

# %% [markdown]
# Code Segment:code require to run
#
# Data Segment:has the list of all global and static variable (whereverin the program it require , we'll able to acces it)
#
# Heap:with this Heap memory we'll able to see dynamically allocation of the memory keep on happening
#
# Stack:it make sure that it has a access of all the local variable function calls
#
# Register: these are smaller memory to store some of the variables , logics for smaller period of time

# %% [markdown]
# #### SEPARATE MEMORY SPACE
#
# Every Process when we run it , thios will have a seperate memory space
#
# Due to this we have:
#
# - One process cannot corrupt another process
# - It reqiure Some other I/O requirement
# - dis: Increase execution time to switch b/w processes

# %% [markdown]
# # Threads
#
# A thread is a unit of execution within a process.
#
# ### Single Threaded Process

# %%
'''''+----------------+----------------+----------------------+
|  Code Segment  |  Data Segment  |         Heap         |
+----------------+----------------+----------------------+
|      Stack     |               Registers              |
+----------------+--------------------------------------+
|                                                      |
|                      S                               |
|                                                      |
|                                                      |
+------------------------------------------------------+'''''
# Out:
# "''+----------------+----------------+----------------------+\n|  Code Segment  |  Data Segment  |         Heap         |\n+----------------+----------------+----------------------+\n|      Stack     |               Registers              |\n+----------------+--------------------------------------+\n|                                                      |\n|                      S                               |\n|                                                      |\n|                                                      |\n+------------------------------------------------------+"

# %%
'''Eg: MS PAINT
        |
        v
      Process
        |
        +---------------------> [   Box   ]
        |                           |
        |                           v
        +---------------------> ( Circle )
                     Thread'''
# Out:
# 'Eg: MS PAINT\n        |\n        v\n      Process\n        |\n        +---------------------> [   Box   ]\n        |                           |\n        |                           v\n        +---------------------> ( Circle )\n                     Thread'

# %% [markdown]
# ### Multi THreaded Process

# %%
'''''+----------------+----------------+----------------------+
|  Code Segment  |  Data Segment  |         Heap         |
+----------------+----------------+----------------------+
|      Stack     |               Registers              |
+----------------+--------------------------------------+
|                         |                            |
|          stack          |             stack          |
|                         |                            |
|                         |                            |
+------------------------------------------------------+'''''
# Out:
# "''+----------------+----------------+----------------------+\n|  Code Segment  |  Data Segment  |         Heap         |\n+----------------+----------------+----------------------+\n|      Stack     |               Registers              |\n+----------------+--------------------------------------+\n|                         |                            |\n|          stack          |             stack          |\n|                         |                            |\n|                         |                            |\n+------------------------------------------------------+"
