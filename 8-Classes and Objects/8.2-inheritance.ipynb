# %% [markdown]
# ### Inheritance In Python
#
# Inheritance is a fundamental concept in OOP that allows a class to inherit attributes and methods from another class.This lesson covers single inheritance nd multiple inheritance , dmonstarting how to create and use them in python

# %%
# Inheritance in programming, similar to real life,
#  allows a child class (subclass) to inherit properties and 
# behaviors from a parent class (superclass), promoting code reuse and establishing a hierarchy. 

#example :Family Inheritance: A child inherits eye color, surname, and traits from their parents.

# %%
## Inheritance
## Parent class

class Car:
    def __init__(self,windows,doors,enginetype):             # when we create class we have to create cunstroctor
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype

    def drive(self):
        print(f"the person will drive {self.enginetype} car ")

# %%
car1=Car(4,4,"petrol")   # we create object
car1.drive()
# Out:
# the person will drive petrol car

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)  # we have to use super() to call parent class constructor
        self.is_selfdriving=is_selfdriving

    def selfdriving(self):
        print(f"the person will drive {self.enginetype} car with selfdriving")

# %%
car2= Tesla(4,4,"petrol",True)
car2.selfdriving()
car2.drive()
# Out:
# the person will drive petrol car with selfdriving
# the person will drive petrol car

# %%
## Multiple Inheritance
## when  class inherit multiple from more than one base class

## base class1
class Animal:
    def __init__(self,name):
        self.name=name

    def speak(self):
        print("Subclass must implement this method")

## base class2  
class Pet:
    def __init__(self,owner):
        self.owner=owner


## Derived class
class Dog(Animal,Pet): 
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)


    def speak(self):
        return f"{self.name} says woof!"

# %%
## create an object

dog1=Dog("Tom","Shinchan")
print(dog1.speak())
print(dog1.owner)
# Out:
# Tom says woof!
# Shinchan
