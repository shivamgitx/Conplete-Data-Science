# %% [markdown]
# ## Magic Methods or Dunder method
#
# Magic metods in python, are also k/as Dunder methods (double underscore methods)

# %% [markdown]
# ## Magic Methods or Dunder methods
#
# Magic methods are predefined methods in python that you can override to change the behavior of your objects.
# Some magic methods are include:

# %%
'''
__init__: Initialize a new instance of a class.
__str__: Returns a string representation of an object.
__repr__: Returns an official string representation of an object.
__len__: Returns the length of an object.
__getitem__: Gets an item from a container.
__setitem__: Sets an item in a container.
'''
# Out:
# '\n__init__: Initialize a new instance of a class.\n__str__: Returns a string representation of an object.\n__repr__: Returns an official string representation of an object.\n__len__: Returns the length of an object.\n__getitem__: Gets an item from a container.\n__setitem__: Sets an item in a container.\n'

# %%
class Person:
    pass

person=Person()
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
print(person)

# %%
## Basic MAgic Method
class Person:
   def __init__(self,name,age):
      self.name=name
      self.age=age

person=Person("Shivam",23)      
print(person)

# %%
##overriding magic method

## Basic MAgic Method
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def __str__(self):
        return f"{self.name} is {self.age} years old"
    

    def __repr__(self):
        return f"Person(name={self.name},age={self.age})"

person=Person("Shivam",23)      
print(person)
print(repr(person))
# Out:
# Shivam is 23 years old
# Person(name=Shivam,age=23)
