# %% [markdown]
# ## Introduction to Streamlit
#
# Streamlit is an open source app framework for machine learning and data science projects. It allows you to create beautiful web applications for your machine learning and data science projects with sample python scipts.
